# %% [markdown]
# <a href="https://colab.research.google.com/github/Aayus001/Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import DataFrame, read_csv
# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number

# %%
name= ['Kunal','Aayush','Yash','Rahul','Amit','Mayank']
Eno= [31,1,69,48,8,35]
Data= list(zip(name,Eno))
Data
# Out:
# [('Kunal', 31),
#  ('Aayush', 1),
#  ('Yash', 69),
#  ('Rahul', 48),
#  ('Amit', 8),
#  ('Mayank', 35)]

# %%
df= pd.DataFrame(data= Data,columns= ('name','enroll'))
df
# Out:
#      name  enroll
# 0   Kunal      31
# 1  Aayush       1
# 2    Yash      69
# 3   Rahul      48
# 4    Amit       8
# 5  Mayank      35

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df= pd.read_csv("/content/drive/MyDrive/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.tail(15)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1= pd.read_csv("/content/drive/MyDrive/statewisetestingsamples.csv")
df1
# Out:
#             Date                        State  TotalSamples  Negative  Positive
# 0     17/04/2020  Andaman and Nicobar Islands          1403    1210.0      12.0
# 1     24/04/2020  Andaman and Nicobar Islands          2679       NaN      27.0
# 2     27/04/2020  Andaman and Nicobar Islands          2848       NaN      33.0
# 3     01/05/2020  Andaman and Nicobar Islands          3754       NaN      33.0
# 4     16/05/2020  Andaman and Nicobar Islands          6677       NaN      33.0
# ...          ...                          ...           ...       ...       ...
# 1770  01/06/2020                  West Bengal        213231       NaN    5772.0
# 1771  02/06/2020                  West Bengal        222726       NaN    6168.0
# 1772  03/06/2020                  West Bengal        232225       NaN    6508.0
# 1773  04/06/2020                  West Bengal        241831       NaN    6876.0
# 1774  05/06/2020                  West Bengal        251517       NaN    7303.0
#
# ...

# %%
df2= pd.read_csv("/content/drive/MyDrive/Salary_Data.csv")
df2
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df1.dtypes
# Out:
# Date             object
# State            object
# TotalSamples      int64
# Negative        float64
# Positive        float64
# dtype: object

# %%
df2.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df1.sort_values(['Positive'],ascending= False)
# Out:
#             Date        State  TotalSamples  Negative  Positive
# 1049  06/06/2020  Maharashtra        538009  451764.0   80229.0
# 1048  05/06/2020  Maharashtra        524002  440445.0   77793.0
# 1047  04/06/2020  Maharashtra        511136  430100.0   74860.0
# 1046  03/06/2020  Maharashtra        498577  420644.0   72300.0
# 1045  02/06/2020  Maharashtra        484784  409178.0   70013.0
# ...          ...          ...           ...       ...       ...
# 1715  06/04/2020  West Bengal          1301       NaN       NaN
# 1716  07/04/2020  West Bengal          1487       NaN       NaN
# 1717  09/04/2020  West Bengal          1889       NaN       NaN
# 1718  10/04/2020  West Bengal          2095       NaN       NaN
# 1739  01/05/2020  West Bengal         18566       NaN       NaN
#
# [1775 rows x 5 columns]

# %%
df2.sort_values(['Salary'],ascending= True)
# Out:
#     YearsExperience    Salary
# 2               1.5   37731.0
# 0               1.1   39343.0
# 4               2.2   39891.0
# 3               2.0   43525.0
# 1               1.3   46205.0
# 7               3.2   54445.0
# 11              4.0   55794.0
# 5               2.9   56642.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 9               3.7   57189.0
# 6               3.0   60150.0
# 14              4.5   61111.0
# 10              3.9   63218.0
# 8               3.2   64445.0
# 16              5.1   66029.0
# 15              4.9   67938.0
# 18              5.9   81363.0
# 17              5.3   83088.0
# 20              6.8   91738.0
# 19              6.0   93940.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 25              9.0  105582.0
# 24              8.7  109431.0
# 27              9.6  112635.0
# 23              8.2  113812.0
# 26              9.5  116969.0
# 29             10.5  121872.0
# 28             10.3  122391.0

# %%
Sorted=df2.sort_values(['Salary'],ascending= True)
Sorted.head(5)
# Out:
#    YearsExperience   Salary
# 2              1.5  37731.0
# 0              1.1  39343.0
# 4              2.2  39891.0
# 3              2.0  43525.0
# 1              1.3  46205.0

# %%
df.loc[50]
# Out:
# Pregnancies                   1.000
# Glucose                     103.000
# BloodPressure                80.000
# SkinThickness                11.000
# Insulin                      82.000
# BMI                          19.400
# DiabetesPedigreeFunction      0.491
# Age                          22.000
# Outcome                       0.000
# Name: 50, dtype: float64

# %%
df1.loc[60]
# Out:
# Date                03/06/2020
# State           Andhra Pradesh
# TotalSamples            403747
# Negative              399776.0
# Positive                3279.0
# Name: 60, dtype: object

# %%
df1.rank()
# Out:
#         Date   State  TotalSamples  Negative  Positive
# 0      927.5     3.5         239.0     150.0     301.0
# 1     1346.0     3.5         340.0       NaN     382.5
# 2     1520.5     3.5         350.0       NaN     419.5
# 3       18.5     3.5         417.0       NaN     419.5
# 4      897.5     3.5         579.5       NaN     419.5
# ...      ...     ...           ...       ...       ...
# 1770    48.5  1744.5        1631.0       NaN    1576.0
# 1771   116.0  1744.5        1643.0       NaN    1584.0
# 1772   181.5  1744.5        1653.0       NaN    1594.0
# 1773   247.0  1744.5        1664.0       NaN    1603.0
# 1774   318.5  1744.5        1671.0       NaN    1614.0
#
# [1775 rows x 5 columns]

# %%
g= df1.groupby("State")
g
